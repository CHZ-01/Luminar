# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !unzip /content/EDA.zip
# Out:
# Archive:  /content/EDA.zip
#    creating: EDA/Feature_engineering/
#   inflating: EDA/Feature_engineering/Feature_engineering.csv
#   inflating: EDA/final_eda.csv
#    creating: EDA/group_order_join/
#   inflating: EDA/group_order_join/sample_data1.csv
#   inflating: EDA/group_order_join/sample_data2.csv
#    creating: EDA/Missing_value_handling/
#   inflating: EDA/Missing_value_handling/sample_with_missing_values.csv
#   inflating: EDA/Missing_value_handling/sample_with_special_missing_values.csv
#    creating: EDA/Pandas_basics/
#   inflating: EDA/Pandas_basics/access-code.csv
#   inflating: EDA/Pandas_basics/annual-enterprise-survey-2021-financial-year-provisional-size-bands1-csv.csv
#   inflating: EDA/Pandas_basics/annual-enterprise-survey-2021-financial-year-provisional-size-bands-csv.csv
#   inflating: EDA/Pandas_basics/email.csv
#   inflating: EDA/without_Col_name.csv

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DataSet/EDA/Feature_engineering/Feature_engineering.csv")
df.head()
# Out:
#      datetime  numeric_col1  numeric_col2 category_col Velocity
# 0  01-01-2024      1.764052     -0.895467            A    51m/s
# 1  02-01-2024      0.400157      0.386902            A        4
# 2  03-01-2024      0.978738     -0.510805            B       32
# 3  04-01-2024      2.240893     -1.180632            C       10
# 4  05-01-2024      1.867558     -0.028182            B       11

# %%
df["datetime"] = pd.to_datetime(df["datetime"],format="%d-%m-%Y")

# %%
df["Velocity"] = df["Velocity"].str.strip(" m/s")
df["Velocity"] = df["Velocity"].astype("int")

# %%
df.dtypes
# Out:
# datetime        datetime64[ns]
# numeric_col1           float64
# numeric_col2           float64
# category_col            object
# Velocity                 int64
# dtype: object

# %%
data1 = [[1,'John'], [2,'Robert'], [3,'David'], [4,'John'], [5,'Betty']]
data2 = [[1, 200,10], [2, 500,3], [3,300,6], [4,800,5], [5,150,8]]

customers = pd.DataFrame(data1,columns=['customer_id', 'first_name'])
orders = pd.DataFrame(data2,columns=['order_id','amount','customer_id'])

pd.merge(customers,orders,on='customer_id',how='inner')
pd.merge(customers,orders,on='customer_id',how='left')
pd.merge(customers,orders,on='customer_id',how='right')
pd.merge(customers,orders,on='customer_id',how='outer')
# pd.merge(customers,orders,how='outer',left_on='customer_id',right_on='id')
# Out:
#    customer_id first_name  order_id  amount
# 0            1       John       NaN     NaN
# 1            2     Robert       NaN     NaN
# 2            3      David       2.0   500.0
# 3            4       John       NaN     NaN
# 4            5      Betty       4.0   800.0
# 5            6        NaN       3.0   300.0
# 6            8        NaN       5.0   150.0
# 7           10        NaN       1.0   200.0

# %%
pd.concat([orders,customers],ignore_index=True)
# Out:
#    order_id  amount  customer_id first_name
# 0       1.0   200.0           10        NaN
# 1       2.0   500.0            3        NaN
# 2       3.0   300.0            6        NaN
# 3       4.0   800.0            5        NaN
# 4       5.0   150.0            8        NaN
# 5       NaN     NaN            1       John
# 6       NaN     NaN            2     Robert
# 7       NaN     NaN            3      David
# 8       NaN     NaN            4       John
# 9       NaN     NaN            5      Betty
